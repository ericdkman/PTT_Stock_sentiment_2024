# %%
import getpass
import os
import json
import pandas as pd
import functools
import operator
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_experimental.tools import PythonREPLTool 
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langgraph.graph import END, StateGraph, START
from langchain_core.output_parsers.openai_functions import JsonOutputFunctionsParser
from typing import Sequence, TypedDict, Annotated

def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"Please provide your {var}")

# 設置環境變量
_set_if_undefined("OPENAI_API_KEY")
_set_if_undefined("OPENAI_ORGANIZATION")
_set_if_undefined("LANGCHAIN_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# Optional, add tracing in LangSmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "Multi-agent Collaboration"

# 读取CSV文件
file_path = "ptt_stock_posts_num1.csv"
df = pd.read_csv(file_path)

# 预览数据
print(df.head())

# 定義工具
tavily_tool = TavilySearchResults(max_results=5)
python_repl_tool = PythonREPLTool() 

# 定義代理
def create_agent(llm: ChatOpenAI, tools: list, system_prompt: str):
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            MessagesPlaceholder(variable_name="messages"),
            MessagesPlaceholder(variable_name="agent_scratchpad"),
        ]
    )
    agent = create_openai_tools_agent(llm, tools, prompt)
    executor = AgentExecutor(agent=agent, tools=tools)
    return executor

def agent_node(state, agent, name):
    # 獲取原始內容
    original_content = state.get("original_content", "")
    
    # 獲取之前的消息歷史
    previous_messages = state["messages"]
    
    # 根據 agent 的角色構建新的輸入消息
    if name == "Analysis_1":
        new_message = HumanMessage(content=f"Analyze the sentiment of the following content: {original_content}")
    else:  # Analysis_final
        previous_analysis = previous_messages[-1].content if previous_messages else ""
        new_message = HumanMessage(content=f"Given the following original content and previous analysis, provide a comprehensive financial sentiment analysis:\n\nOriginal content: {original_content}\n\nPrevious analysis: {previous_analysis}")
    
    # 將新消息添加到狀態中
    updated_state = {
        "messages": previous_messages + [new_message],
        "original_content": original_content
    }
    
    # 調用 agent
    result = agent.invoke(updated_state)
    
    # 返回更新後的狀態
    return {
        "messages": updated_state["messages"] + [HumanMessage(content=result["output"], name=name)],
        "original_content": original_content
    }
    
    

members = ["Analysis_1", "Analysis_final"]
system_prompt = (
    "You are a supervisor tasked with managing a conversation between the"
    " following workers: {members}. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH."
)
options = ["FINISH"] + members
function_def = {
    "name": "route",
    "description": "Select the next role.",
    "parameters": {
        "title": "routeSchema",
        "type": "object",
        "properties": {
            "next": {
                "title": "Next",
                "anyOf": [{"enum": options}],
            }
        },
        "required": ["next"],
    },
}
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "Given the conversation above, who should act next?"
            " Or should we FINISH? Select one of: {options}",
        ),
    ]
).partial(options=str(options), members=", ".join(members))

llm = ChatOpenAI(model="gpt-4o")

supervisor_chain = (
    prompt
    | llm.bind_functions(functions=[function_def], function_call="route")
    | JsonOutputFunctionsParser()
)

class AgentState(TypedDict):
    messages: Sequence[BaseMessage]
    next: str
    original_content: str

research_agent = create_agent(llm, [tavily_tool], "You are a investor. Analyze the sentiment of the given financial content.")
research_node = functools.partial(agent_node, agent=research_agent, name="Analysis_1")

# code_agent = create_agent(llm,[python_repl_tool], "You may generate charts using matplotlib.")
# code_node = functools.partial(agent_node, agent=code_agent, name="Coder")

finance_sentiment_agent = create_agent(llm, [tavily_tool], "You are a financial sentiment analysis expert. Analyze the sentiment of the given financial content.")
finance_sentiment_node = functools.partial(agent_node, agent=finance_sentiment_agent, name="Analysis_final")

workflow = StateGraph(AgentState)
workflow.add_node("Analysis_1", research_node) 
workflow.add_node("Analysis_final", finance_sentiment_node)
# workflow.add_node("Coder", code_node)
workflow.add_node("supervisor", supervisor_chain)

for member in members:
    workflow.add_edge(member, "supervisor")
conditional_map = {k: k for k in members}
conditional_map["FINISH"] = END
workflow.add_conditional_edges("supervisor", lambda x: x["next"], conditional_map)
workflow.add_edge(START, "supervisor")

graph = workflow.compile()

# 流式處理每篇文章
for index, row in df.iterrows():
    article_content = row['Content']
    
    # 創建 HumanMessage 對象
    input_message_content = HumanMessage(content=f"Analyze the sentiment of the following content: {article_content}")
    
    # 將消息對象包裝成字典格式
    messages_dict = {
        "messages": [input_message_content],  # 使用 "messages" 鍵
        "original_content": article_content
    }
    
    # 流式處理
    for s in graph.stream(messages_dict):
        if "__end__" not in s:
            print(s)
            print("----")

print('done')
# Out:
#    Unnamed: 0                 Title           Author  \
# 0           0  [閒聊] 2024/07/17 盤中閒聊  vendan5566 (阿文)
#
#                        Date  \
# 0  Wed Jul 17 08:30:00 2024
#
#                                              Content  \
# 0  \n=============113/07/17台股資訊重點整理，供股民做投資參考=====...
#
#                                                 Link  \
# 0  https://www.ptt.cc/bbs/Stock/M.1721176202.A.78...
#
#                                               Pushes
# 0  {"0":{"Tag":"ARROW","Userid":"MOMO0478","Conte...
# {'supervisor': {'next': 'Analysis_1'}}
# ----
# {'Analysis_1': {'messages': [HumanMessage(content='Analyze the sentiment of the following content: \n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------------------------------------\n道瓊工業40954.48▲742.76(1.85%)\n那斯達克18509.34▲ 36.77(0.20%)\n標普500  5667.20▲ 35.98(0.64%)\n費城半導 5804.03▲ 26.32(0.46%)\n----------------------------------------\n川登基 殺台積 空軍喜 現生機\n雯晴：今天月結算唷\n--\nhttps://i.imgur.com/NvzRhwU.jpg\n--\n'), HumanMessage(content='Analyze the sentiment of the following content: \n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------------------------------------\n道瓊工業40954.48▲742.76(1.85%)\n那斯達克18509.34▲ 36.77(0.20%)\n標普500  5667.20▲ 35.98(0.64%)\n費城半導 5804.03▲ 26.32(0.46%)\n----------------------------------------\n川登基 殺台積 空軍喜 現生機\n雯晴：今天月結算唷\n--\nhttps://i.imgur.com/NvzRhwU.jpg\n--\n'), HumanMessage(content='The sentiment of the provided financial content can be analyzed as follows:\n\n1. **Market Performance:**\n   - **台股 (Taiwan Stock Exchange):** The overall index has risen by 0.49%, indicating a positive sentiment.\n   - **台指0724002 (Taiwan Index Futures):** Increased by 0.63%, reflecting optimism in future market performance.\n   - **盤後0724064 (Post-market Futures):** Also increased by 0.29%, suggesting positive sentiment extending into after-hours trading.\n\n2. **Open Interest:**\n   - **自營商 (Proprietary Traders):** Decrease in open interest for index futures (-6,029) might indicate a bearish sentiment among proprietary traders. However, the significant increase in open interest in index options (+9,982) could suggest hedging activities.\n   - **投信 (Investment Trusts):** Increase in open interest for index futures (+421) shows a bullish sentiment.\n   - **外資 (Foreign Investors):** Significant decrease in open interest for index futures (-932) and a moderate increase in options (+541) which may reflect a cautious or mixed sentiment.\n\n3. **International Markets:**\n   - **道瓊工業 (Dow Jones):** Increased by 1.85%, showing strong positive sentiment.\n   - **那斯達克 (NASDAQ):** Slight increase by 0.20%, indicating a mildly positive sentiment.\n   - **標普500 (S&P 500):** Increased by 0.64%, suggesting a positive sentiment.\n   - **費城半導 (Philadelphia Semiconductor Index):** Increased by 0.46%, reflecting positive sentiment in the semiconductor sector.\n\n4. **Additional Commentary:**\n   - The mention of "川登基 殺台積 空軍喜 現生機" could be interpreted as a mixed or cautious sentiment, possibly referring to geopolitical influences or specific stock movements (e.g., TSMC).\n   - The remark by "雯晴" about the monthly settlement hints at a strategic period for investors, which might affect short-term sentiment and trading activities.\n\n**Overall Sentiment:** The sentiment of the content is predominantly positive, with rising indices and positive movements in both the local (Taiwan) and international markets. However, there are cautious undertones from proprietary traders and foreign investors, suggesting mixed sentiment in some areas.', name='Analysis_1')], 'original_content': '\n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------------------------------------\n道瓊工業40954.48▲742.76(1.85%)\n那斯達克18509.34▲ 36.77(0.20%)\n標普500  5667.20▲ 35.98(0.64%)\n費城半導 5804.03▲ 26.32(0. ...
# ----
# {'supervisor': {'next': 'Analysis_final'}}
# ----
# {'Analysis_final': {'messages': [HumanMessage(content='Analyze the sentiment of the following content: \n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------------------------------------\n道瓊工業40954.48▲742.76(1.85%)\n那斯達克18509.34▲ 36.77(0.20%)\n標普500  5667.20▲ 35.98(0.64%)\n費城半導 5804.03▲ 26.32(0.46%)\n----------------------------------------\n川登基 殺台積 空軍喜 現生機\n雯晴：今天月結算唷\n--\nhttps://i.imgur.com/NvzRhwU.jpg\n--\n'), HumanMessage(content='Analyze the sentiment of the following content: \n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------------------------------------\n道瓊工業40954.48▲742.76(1.85%)\n那斯達克18509.34▲ 36.77(0.20%)\n標普500  5667.20▲ 35.98(0.64%)\n費城半導 5804.03▲ 26.32(0.46%)\n----------------------------------------\n川登基 殺台積 空軍喜 現生機\n雯晴：今天月結算唷\n--\nhttps://i.imgur.com/NvzRhwU.jpg\n--\n'), HumanMessage(content='The sentiment of the provided financial content can be analyzed as follows:\n\n1. **Market Performance:**\n   - **台股 (Taiwan Stock Exchange):** The overall index has risen by 0.49%, indicating a positive sentiment.\n   - **台指0724002 (Taiwan Index Futures):** Increased by 0.63%, reflecting optimism in future market performance.\n   - **盤後0724064 (Post-market Futures):** Also increased by 0.29%, suggesting positive sentiment extending into after-hours trading.\n\n2. **Open Interest:**\n   - **自營商 (Proprietary Traders):** Decrease in open interest for index futures (-6,029) might indicate a bearish sentiment among proprietary traders. However, the significant increase in open interest in index options (+9,982) could suggest hedging activities.\n   - **投信 (Investment Trusts):** Increase in open interest for index futures (+421) shows a bullish sentiment.\n   - **外資 (Foreign Investors):** Significant decrease in open interest for index futures (-932) and a moderate increase in options (+541) which may reflect a cautious or mixed sentiment.\n\n3. **International Markets:**\n   - **道瓊工業 (Dow Jones):** Increased by 1.85%, showing strong positive sentiment.\n   - **那斯達克 (NASDAQ):** Slight increase by 0.20%, indicating a mildly positive sentiment.\n   - **標普500 (S&P 500):** Increased by 0.64%, suggesting a positive sentiment.\n   - **費城半導 (Philadelphia Semiconductor Index):** Increased by 0.46%, reflecting positive sentiment in the semiconductor sector.\n\n4. **Additional Commentary:**\n   - The mention of "川登基 殺台積 空軍喜 現生機" could be interpreted as a mixed or cautious sentiment, possibly referring to geopolitical influences or specific stock movements (e.g., TSMC).\n   - The remark by "雯晴" about the monthly settlement hints at a strategic period for investors, which might affect short-term sentiment and trading activities.\n\n**Overall Sentiment:** The sentiment of the content is predominantly positive, with rising indices and positive movements in both the local (Taiwan) and international markets. However, there are cautious undertones from proprietary traders and foreign investors, suggesting mixed sentiment in some areas.', name='Analysis_1'), HumanMessage(content='Given the following original content and previous analysis, provide a comprehensive financial sentiment analysis:\n\nOriginal content: \n=============113/07/17台股資訊重點整理，供股民做投資參考============\n台股  23997.25▲117.89(+0.49%)成交量4670.50億\n台指0724002   ▲151   (+0.63%)成交量115,651口\n盤後0724064   ▲ 70   (+0.29%)成交量 56,487口\n\n台指期未平倉口數自營商 -6,029(   -179)投信+21,216(  +421)外資-37,134(   -932)\n台指選未平倉口數自營商-14,169( +9,982)投信     +3(     0)外資 -8,954(   +541)\n\n----------- ...
# ----
# {'supervisor': {'next': 'FINISH'}}
# ----
# done
